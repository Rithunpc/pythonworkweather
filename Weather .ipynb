# %% [markdown]
# Weather data

# %%
 import pandas as pd ,numpy as np,matplotlib.pyplot as plt,seaborn as sns

# %%
dict_line= {
    'Day':['Tue 9','Wed 10','Thu 11','Fri 12','Sat 13','Sun 14','Mon 15','Tue 16','Wed 17','Thu 18'],
    'Temperature':[33,33,33,31,31,32,33,33,33,33],
    'Hourly Forecast':['58%','20%','69%','89%','63%','19%','20%','13%','12%','23%']
 }
dt_line = pd.DataFrame(dict_line)
dt_line
# Out:
#       Day  Temperature Hourly Forecast
# 0   Tue 9           33             58%
# 1  Wed 10           33             20%
# 2  Thu 11           33             69%
# 3  Fri 12           31             89%
# 4  Sat 13           31             63%
# 5  Sun 14           32             19%
# 6  Mon 15           33             20%
# 7  Tue 16           33             13%
# 8  Wed 17           33             12%
# 9  Thu 18           33             23%

# %%
dt_line.plot('Day','Temperature')
# Out:
# <Axes: xlabel='Day'>
